-- %% [markdown]
-- # [Profcom_DB]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Profcom_DB]    Script Date: 24.04.2022 19:47:18 ******/
CREATE DATABASE [Profcom_DB]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'Profcom_DB', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\Profcom_DB.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'Profcom_DB_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\Profcom_DB_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Profcom_DB].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Profcom_DB] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Profcom_DB] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Profcom_DB] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Profcom_DB] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Profcom_DB] SET ARITHABORT OFF 
GO
ALTER DATABASE [Profcom_DB] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [Profcom_DB] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Profcom_DB] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Profcom_DB] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Profcom_DB] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Profcom_DB] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Profcom_DB] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Profcom_DB] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Profcom_DB] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Profcom_DB] SET  DISABLE_BROKER 
GO
ALTER DATABASE [Profcom_DB] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Profcom_DB] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Profcom_DB] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Profcom_DB] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Profcom_DB] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Profcom_DB] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Profcom_DB] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Profcom_DB] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [Profcom_DB] SET  MULTI_USER 
GO
ALTER DATABASE [Profcom_DB] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Profcom_DB] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Profcom_DB] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Profcom_DB] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [Profcom_DB] SET DELAYED_DURABILITY = DISABLED 
GO

-- %% [markdown]
-- # [dbo].[Гендер]

-- %%
USE [Profcom_DB]
GO

-- %%
/****** Object:  Table [dbo].[Гендер]    Script Date: 24.04.2022 19:47:18 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Гендер](
	[Код_пола] [int] IDENTITY(1,1) NOT NULL,
	[Пол] [char](10) NOT NULL,
 CONSTRAINT [PK_Гендер] PRIMARY KEY CLUSTERED 
(
	[Код_пола] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Дети]

-- %%
/****** Object:  Table [dbo].[Дети]    Script Date: 24.04.2022 19:47:18 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Дети](
	[Код_дети] [int] IDENTITY(1,1) NOT NULL,
	[Фамилия] [varchar](50) NOT NULL,
	[Имя] [varchar](50) NOT NULL,
	[Отчество] [varchar](50) NULL,
	[Дата_рождения] [datetime] NOT NULL,
	[Код_пола] [int] NOT NULL,
 CONSTRAINT [PK_Дети] PRIMARY KEY CLUSTERED 
(
	[Код_дети] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Дети_родители]

-- %%
/****** Object:  Table [dbo].[Дети_родители]    Script Date: 24.04.2022 19:47:18 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Дети_родители](
	[Код] [int] IDENTITY(1,1) NOT NULL,
	[Код_дети] [int] NOT NULL,
	[Код_ЧП] [int] NOT NULL,
 CONSTRAINT [PK_Дети_родители] PRIMARY KEY CLUSTERED 
(
	[Код] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Должности]

-- %%
/****** Object:  Table [dbo].[Должности]    Script Date: 24.04.2022 19:47:18 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Должности](
	[Код_должности] [int] IDENTITY(1,1) NOT NULL,
	[Должность] [varchar](max) NOT NULL,
 CONSTRAINT [PK_Должности] PRIMARY KEY CLUSTERED 
(
	[Код_должности] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Заявления]

-- %%
/****** Object:  Table [dbo].[Заявления]    Script Date: 24.04.2022 19:47:18 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Заявления](
	[Код_заявления] [int] IDENTITY(1,1) NOT NULL,
	[Дата_регистрации] [datetime] NOT NULL,
	[Код_ЧП] [int] NOT NULL,
	[Код_ТЗ] [int] NOT NULL,
	[Код_МП] [int] NOT NULL,
	[Код_протокола] [int] NOT NULL,
 CONSTRAINT [PK_Заявления] PRIMARY KEY CLUSTERED 
(
	[Код_заявления] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Материальная_выплата]

-- %%
/****** Object:  Table [dbo].[Материальная_выплата]    Script Date: 24.04.2022 19:47:18 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Материальная_выплата](
	[Код_МП] [int] IDENTITY(1,1) NOT NULL,
	[Сумма] [smallmoney] NOT NULL,
	[Код_основания] [int] NOT NULL,
 CONSTRAINT [PK_Материальная_выплата] PRIMARY KEY CLUSTERED 
(
	[Код_МП] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Общественные_организации]

-- %%
/****** Object:  Table [dbo].[Общественные_организации]    Script Date: 24.04.2022 19:47:18 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Общественные_организации](
	[Код_ОО] [int] IDENTITY(1,1) NOT NULL,
	[Общественные_организации] [varchar](max) NOT NULL,
 CONSTRAINT [PK_Общественные_организации] PRIMARY KEY CLUSTERED 
(
	[Код_ОО] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ОО_ЧП]

-- %%
/****** Object:  Table [dbo].[ОО_ЧП]    Script Date: 24.04.2022 19:47:18 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ОО_ЧП](
	[Код] [int] IDENTITY(1,1) NOT NULL,
	[Код_ОО] [int] NOT NULL,
	[Код_ЧП] [int] NOT NULL,
 CONSTRAINT [PK_ОО_ЧП] PRIMARY KEY CLUSTERED 
(
	[Код] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Основания_МП]

-- %%
/****** Object:  Table [dbo].[Основания_МП]    Script Date: 24.04.2022 19:47:18 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Основания_МП](
	[Код_основания] [int] IDENTITY(1,1) NOT NULL,
	[Основания] [varchar](max) NOT NULL,
 CONSTRAINT [PK_Основания_МП] PRIMARY KEY CLUSTERED 
(
	[Код_основания] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Пользователи]

-- %%
/****** Object:  Table [dbo].[Пользователи]    Script Date: 24.04.2022 19:47:18 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Пользователи](
	[Код_пользователя] [int] IDENTITY(1,1) NOT NULL,
	[Имя_пользователя] [nvarchar](50) NOT NULL,
	[Логин] [nvarchar](50) NOT NULL,
	[Пароль] [nvarchar](50) NOT NULL,
	[Код_типа_пользователя] [int] NOT NULL,
 CONSTRAINT [PK_Пользователи] PRIMARY KEY CLUSTERED 
(
	[Код_пользователя] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Протоколы_заседаний]

-- %%
/****** Object:  Table [dbo].[Протоколы_заседаний]    Script Date: 24.04.2022 19:47:18 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Протоколы_заседаний](
	[Код_протокола] [int] IDENTITY(1,1) NOT NULL,
	[Номер_протокола] [int] NOT NULL,
	[Дата_протокола] [datetime] NOT NULL,
	[Тема_заседания] [varchar](max) NULL,
	[Текст_протокола] [varchar](max) NULL,
 CONSTRAINT [PK_Протоколы_заседаний] PRIMARY KEY CLUSTERED 
(
	[Код_протокола] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Телефоны]

-- %%
/****** Object:  Table [dbo].[Телефоны]    Script Date: 24.04.2022 19:47:18 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Телефоны](
	[Код_номера] [int] IDENTITY(1,1) NOT NULL,
	[Код_ЧП] [int] NOT NULL,
	[Номер_телефона] [varchar](50) NOT NULL,
 CONSTRAINT [PK_Телефоны] PRIMARY KEY CLUSTERED 
(
	[Код_номера] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Типы_заявлений]

-- %%
/****** Object:  Table [dbo].[Типы_заявлений]    Script Date: 24.04.2022 19:47:18 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Типы_заявлений](
	[Код_ТЗ] [int] IDENTITY(1,1) NOT NULL,
	[Тип_заявления] [varchar](max) NOT NULL,
 CONSTRAINT [PK_Типы_заявлений] PRIMARY KEY CLUSTERED 
(
	[Код_ТЗ] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Типы_пользователя]

-- %%
/****** Object:  Table [dbo].[Типы_пользователя]    Script Date: 24.04.2022 19:47:18 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Типы_пользователя](
	[Код_типа_пользователя] [int] IDENTITY(1,1) NOT NULL,
	[Тип_пользователя] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK_Типы_пользователя] PRIMARY KEY CLUSTERED 
(
	[Код_типа_пользователя] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Члены_профсоюза]

-- %%
/****** Object:  Table [dbo].[Члены_профсоюза]    Script Date: 24.04.2022 19:47:18 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Члены_профсоюза](
	[Код_ЧП] [int] IDENTITY(1,1) NOT NULL,
	[Фамилия] [varchar](50) NOT NULL,
	[Имя] [varchar](50) NOT NULL,
	[Отчество] [varchar](50) NULL,
	[Дата_рождения] [datetime] NOT NULL,
	[Код_пола] [int] NOT NULL,
	[Код_должности] [int] NOT NULL,
 CONSTRAINT [PK_Члены_профсоюза] PRIMARY KEY CLUSTERED 
(
	[Код_ЧП] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Гендер]

-- %%
SET IDENTITY_INSERT [dbo].[Гендер] ON 
INSERT [dbo].[Гендер] ([Код_пола], [Пол]) VALUES (1, N'Мужской   ')
INSERT [dbo].[Гендер] ([Код_пола], [Пол]) VALUES (2, N'Женский   ')
SET IDENTITY_INSERT [dbo].[Гендер] OFF
GO

-- %% [markdown]
-- # [dbo].[Должности]

-- %%
SET IDENTITY_INSERT [dbo].[Должности] ON 
INSERT [dbo].[Должности] ([Код_должности], [Должность]) VALUES (1, N'Директор')
INSERT [dbo].[Должности] ([Код_должности], [Должность]) VALUES (2, N'Преподаватель')
INSERT [dbo].[Должности] ([Код_должности], [Должность]) VALUES (3, N'Мастер ПО')
SET IDENTITY_INSERT [dbo].[Должности] OFF
GO

-- %% [markdown]
-- # [dbo].[Телефоны]

-- %%
SET IDENTITY_INSERT [dbo].[Телефоны] ON 
INSERT [dbo].[Телефоны] ([Код_номера], [Код_ЧП], [Номер_телефона]) VALUES (1, 1, N'+375298010358')
SET IDENTITY_INSERT [dbo].[Телефоны] OFF
GO

-- %% [markdown]
-- # [dbo].[Члены_профсоюза]

-- %%
SET IDENTITY_INSERT [dbo].[Члены_профсоюза] ON 
INSERT [dbo].[Члены_профсоюза] ([Код_ЧП], [Фамилия], [Имя], [Отчество], [Дата_рождения], [Код_пола], [Код_должности]) VALUES (1, N'Сыцевич', N'Максим', N'Николаевич', CAST(N'2001-04-22T00:00:00.000' AS DateTime), 1, 2)
SET IDENTITY_INSERT [dbo].[Члены_профсоюза] OFF
GO

-- %% [markdown]
-- # [FK_Дети_Гендер]

-- %%
ALTER TABLE [dbo].[Дети]  WITH CHECK ADD  CONSTRAINT [FK_Дети_Гендер] FOREIGN KEY([Код_пола])
REFERENCES [dbo].[Гендер] ([Код_пола])
GO
ALTER TABLE [dbo].[Дети] CHECK CONSTRAINT [FK_Дети_Гендер]
GO

-- %% [markdown]
-- # [FK_Дети_родители_Дети]

-- %%
ALTER TABLE [dbo].[Дети_родители]  WITH CHECK ADD  CONSTRAINT [FK_Дети_родители_Дети] FOREIGN KEY([Код_дети])
REFERENCES [dbo].[Дети] ([Код_дети])
GO
ALTER TABLE [dbo].[Дети_родители] CHECK CONSTRAINT [FK_Дети_родители_Дети]
GO

-- %% [markdown]
-- # [FK_Дети_родители_Члены_профсоюза]

-- %%
ALTER TABLE [dbo].[Дети_родители]  WITH CHECK ADD  CONSTRAINT [FK_Дети_родители_Члены_профсоюза] FOREIGN KEY([Код_ЧП])
REFERENCES [dbo].[Члены_профсоюза] ([Код_ЧП])
GO
ALTER TABLE [dbo].[Дети_родители] CHECK CONSTRAINT [FK_Дети_родители_Члены_профсоюза]
GO

-- %% [markdown]
-- # [FK_Заявления_Материальная_выплата]

-- %%
ALTER TABLE [dbo].[Заявления]  WITH CHECK ADD  CONSTRAINT [FK_Заявления_Материальная_выплата] FOREIGN KEY([Код_МП])
REFERENCES [dbo].[Материальная_выплата] ([Код_МП])
GO
ALTER TABLE [dbo].[Заявления] CHECK CONSTRAINT [FK_Заявления_Материальная_выплата]
GO

-- %% [markdown]
-- # [FK_Заявления_Протоколы_заседаний]

-- %%
ALTER TABLE [dbo].[Заявления]  WITH CHECK ADD  CONSTRAINT [FK_Заявления_Протоколы_заседаний] FOREIGN KEY([Код_протокола])
REFERENCES [dbo].[Протоколы_заседаний] ([Код_протокола])
GO
ALTER TABLE [dbo].[Заявления] CHECK CONSTRAINT [FK_Заявления_Протоколы_заседаний]
GO

-- %% [markdown]
-- # [FK_Заявления_Типы_заявлений]

-- %%
ALTER TABLE [dbo].[Заявления]  WITH CHECK ADD  CONSTRAINT [FK_Заявления_Типы_заявлений] FOREIGN KEY([Код_ТЗ])
REFERENCES [dbo].[Типы_заявлений] ([Код_ТЗ])
GO
ALTER TABLE [dbo].[Заявления] CHECK CONSTRAINT [FK_Заявления_Типы_заявлений]
GO

-- %% [markdown]
-- # [FK_Заявления_Члены_профсоюза]

-- %%
ALTER TABLE [dbo].[Заявления]  WITH CHECK ADD  CONSTRAINT [FK_Заявления_Члены_профсоюза] FOREIGN KEY([Код_ЧП])
REFERENCES [dbo].[Члены_профсоюза] ([Код_ЧП])
GO
ALTER TABLE [dbo].[Заявления] CHECK CONSTRAINT [FK_Заявления_Члены_профсоюза]
GO

-- %% [markdown]
-- # [FK_Материальная_выплата_Основания_МП]

-- %%
ALTER TABLE [dbo].[Материальная_выплата]  WITH CHECK ADD  CONSTRAINT [FK_Материальная_выплата_Основания_МП] FOREIGN KEY([Код_основания])
REFERENCES [dbo].[Основания_МП] ([Код_основания])
GO
ALTER TABLE [dbo].[Материальная_выплата] CHECK CONSTRAINT [FK_Материальная_выплата_Основания_МП]
GO

-- %% [markdown]
-- # [FK_ОО_ЧП_Общественные_организации]

-- %%
ALTER TABLE [dbo].[ОО_ЧП]  WITH CHECK ADD  CONSTRAINT [FK_ОО_ЧП_Общественные_организации] FOREIGN KEY([Код_ОО])
REFERENCES [dbo].[Общественные_организации] ([Код_ОО])
GO
ALTER TABLE [dbo].[ОО_ЧП] CHECK CONSTRAINT [FK_ОО_ЧП_Общественные_организации]
GO

-- %% [markdown]
-- # [FK_ОО_ЧП_Члены_профсоюза]

-- %%
ALTER TABLE [dbo].[ОО_ЧП]  WITH CHECK ADD  CONSTRAINT [FK_ОО_ЧП_Члены_профсоюза] FOREIGN KEY([Код_ЧП])
REFERENCES [dbo].[Члены_профсоюза] ([Код_ЧП])
GO
ALTER TABLE [dbo].[ОО_ЧП] CHECK CONSTRAINT [FK_ОО_ЧП_Члены_профсоюза]
GO

-- %% [markdown]
-- # [FK_Пользователи_Типы_пользователя]

-- %%
ALTER TABLE [dbo].[Пользователи]  WITH CHECK ADD  CONSTRAINT [FK_Пользователи_Типы_пользователя] FOREIGN KEY([Код_типа_пользователя])
REFERENCES [dbo].[Типы_пользователя] ([Код_типа_пользователя])
GO
ALTER TABLE [dbo].[Пользователи] CHECK CONSTRAINT [FK_Пользователи_Типы_пользователя]
GO

-- %% [markdown]
-- # [FK_Телефоны_Члены_профсоюза]

-- %%
ALTER TABLE [dbo].[Телефоны]  WITH CHECK ADD  CONSTRAINT [FK_Телефоны_Члены_профсоюза] FOREIGN KEY([Код_ЧП])
REFERENCES [dbo].[Члены_профсоюза] ([Код_ЧП])
GO
ALTER TABLE [dbo].[Телефоны] CHECK CONSTRAINT [FK_Телефоны_Члены_профсоюза]
GO

-- %% [markdown]
-- # [FK_Члены_профсоюза_Гендер1]

-- %%
ALTER TABLE [dbo].[Члены_профсоюза]  WITH CHECK ADD  CONSTRAINT [FK_Члены_профсоюза_Гендер1] FOREIGN KEY([Код_пола])
REFERENCES [dbo].[Гендер] ([Код_пола])
GO
ALTER TABLE [dbo].[Члены_профсоюза] CHECK CONSTRAINT [FK_Члены_профсоюза_Гендер1]
GO

-- %% [markdown]
-- # [FK_Члены_профсоюза_Должности1]

-- %%
ALTER TABLE [dbo].[Члены_профсоюза]  WITH CHECK ADD  CONSTRAINT [FK_Члены_профсоюза_Должности1] FOREIGN KEY([Код_должности])
REFERENCES [dbo].[Должности] ([Код_должности])
GO
ALTER TABLE [dbo].[Члены_профсоюза] CHECK CONSTRAINT [FK_Члены_профсоюза_Должности1]
GO

-- %% [markdown]
-- # [Profcom_DB]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Profcom_DB] SET  READ_WRITE 
GO
